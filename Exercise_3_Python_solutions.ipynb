# %% [markdown]
# ## Exercise 3

# %%
# Upload Python modules
import networkx as nx
import pandas as pd
import numpy as np
from networkx.algorithms.approximation import steiner_tree
import separation # from Barabasi-lab
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# ### Part A
# - Read the human interactome as network. Explore the network and assess its topological properties (number of nodes and edges, density, number of connected components, modularity etc).

# %%
# Reading the network
edge_list = pd.read_csv("Data/Exercise3_STRING_PPI.csv")
edge_list.head()
# Out:
#                protein1              protein2  neighborhood  fusion  \
# 0  9606.ENSP00000000233  9606.ENSP00000493357             0       0
# 1  9606.ENSP00000000233  9606.ENSP00000371175             0       0
# 2  9606.ENSP00000000233  9606.ENSP00000354878             0       0
# 3  9606.ENSP00000000233  9606.ENSP00000310226             0       0
# 4  9606.ENSP00000000233  9606.ENSP00000258098             0       0
#
#    cooccurence  coexpression  experimental  database  textmining  \
# 0            0            56            53         0         433
# 1            0            47           296         0         403
# 2            0            42             0       500           0
# 3            0           109           110       500         154
# 4            0             0             0         0         497
#
#    combined_score Node1_geneSymbol Node2_geneSymbol
# 0             471             ARF5            CYTH2
# 1             594             ARF5             GGA1
# 2             513             ARF5           KIF21A
# 3             648             ARF5            RAB1B
# 4             501             ARF5        RAB11FIP5

# %%
# edge_list = edge_list[edge_list["combined_score"] > 700]
edge_list.hist("combined_score")
# Out:
# array([[<Axes: title={'center': 'combined_score'}>]], dtype=object)

# %%
# Creating network from edge list 
STRING_PPI = nx.from_pandas_edgelist(df = edge_list,
                            source = "Node1_geneSymbol", 
                            target = "Node2_geneSymbol")
# STRING_PPI_pos = nx.spring_layout(STRING_PPI, seed = 20)
# nx.draw(STRING_PPI, with_labels = False, pos = STRING_PPI_pos, node_size = 1, node_color = "#1BB3F5")

# %%
# Get basic properties of the network
print("Number of nodes:", STRING_PPI.number_of_nodes())
print("Number of edges:", STRING_PPI.number_of_edges())
print("Number of connected components:", nx.number_connected_components(STRING_PPI))
print("Network modularity:", nx.algorithms.community.modularity(STRING_PPI, nx.connected_components(STRING_PPI)))
print("Number of isolated nodes:", nx.number_of_isolates(STRING_PPI))
print("Number of self loops:", nx.number_of_selfloops(STRING_PPI))
# Out:
# Number of nodes: 18876
# Number of edges: 884457
# Number of connected components: 2
# Network modularity: 2.2612718750286577e-06
# Number of isolated nodes: 0
# Number of self loops: 6

# %%
# Extract the largest connected component
STRING_PPI = list(STRING_PPI.subgraph(c).copy() for c in sorted(nx.connected_components(STRING_PPI), key = len, reverse = True))[0]
print(len(STRING_PPI.nodes()), len(STRING_PPI.edges()))
# nx.draw(STRING_PPI, with_labels = False, node_size = 1, node_color = "#1BB3F5")
# Out:
# 18874 884456

# %%
# Remove the self-loops
STRING_PPI.remove_edges_from(list(nx.selfloop_edges(STRING_PPI)))

# %%
# Get basic properties of the network
print("Number of nodes:", STRING_PPI.number_of_nodes())
print("Number of edges:", STRING_PPI.number_of_edges())
print("Number of connected components:", nx.number_connected_components(STRING_PPI))
print("Network modularity:", nx.algorithms.community.modularity(STRING_PPI, nx.connected_components(STRING_PPI)))
print("Number of isolated nodes:", nx.number_of_isolates(STRING_PPI))
print("Number of self loops:", nx.number_of_selfloops(STRING_PPI))
# print("Diameter of network:", nx.diameter(STRING_PPI))
# print("Average clustering coefficient:", nx.average_clustering(STRING_PPI))
# print("Average shortest path length:", nx.average_shortest_path_length(STRING_PPI))
print("Network density:", nx.density(STRING_PPI))
# Out:
# Number of nodes: 18874
# Number of edges: 884450
# Number of connected components: 1
# Network modularity: 0.0
# Number of isolated nodes: 0
# Number of self loops: 0
# Network density: 0.004965904820114568

# %% [raw]
# # Find the top five nodes with highest centralities [takes long time]
# degree_centrality = nx.degree_centrality(STRING_PPI)
# betweenness_centrality = nx.betweenness_centrality(STRING_PPI)
# closeness_centrality = nx.closeness_centrality(STRING_PPI)
#
# centrality_table = pd.DataFrame({"Degree centrality" : pd.Series(degree_centrality),
#                                     "Betweenness" : pd.Series(betweenness_centrality),
#                                     "Closeness centrality" : pd.Series(closeness_centrality)})
#
# print(centrality_table.sort_values(by = "Degree centrality", ascending = False)[0:5].index.values)
# print(centrality_table.sort_values(by = "Betweenness", ascending = False)[0:5].index.values)
# print(centrality_table.sort_values(by = "Closeness centrality", ascending = False)[0:5].index.values)

# %% [markdown]
# ### Part B
# - Extract the sub-network of the disease genes and assess its topological properties.

# %%
# Read the disease gene list
disease_genes = pd.read_csv("Data/Exercise3_Disease_genes.csv")
disease_genes = disease_genes.loc[:,"x"].tolist()
print("Disease genes: ", disease_genes)
print("Number of disease genes: ", len(disease_genes))
# Out:
# Disease genes:  ['ACVR1C', 'ANKK1', 'ATR', 'AURKC', 'BMP2K', 'CSF1R', 'DCLK3', 'DDR1', 'DDR2', 'EGFR', 'EPHA2', 'EPHA3', 'EPHA5', 'ERBB4', 'FGFR1', 'FGFR2', 'FYN', 'GUCY2F', 'IGF1R', 'KRAS', 'MAP2K4', 'MAP3K15', 'MAP4K3', 'MAST4', 'MYLK4', 'MYO18B', 'NOTCH1', 'PLK1', 'PRKDC', 'TRIM24', 'TTN', 'WNK3']
# Number of disease genes:  32

# %%
# Keep only disease genes present in the network
disease_genes = [gene for gene in disease_genes if gene in STRING_PPI.nodes()]
print("Number of disease genes in the network: ", len(disease_genes))
# Out:
# Number of disease genes in the network:  31

# %%
# Extract the sub-network of the known disease genes
disease_subnet = STRING_PPI.subgraph(disease_genes)
disease_subnet_pos = nx.spring_layout(disease_subnet, seed = 20)
nx.draw(disease_subnet, with_labels = False, pos = disease_subnet_pos, node_size = 10, node_color = "#1BB3F5", width = 0.5)

# %%
# Get basic properties of the network
print("Number of nodes:", disease_subnet.number_of_nodes())
print("Number of edges:", disease_subnet.number_of_edges())
print("Number of connected components:", nx.number_connected_components(disease_subnet))
print("Network modularity:", nx.algorithms.community.modularity(disease_subnet, nx.connected_components(disease_subnet)))
print("Number of isolated nodes:", nx.number_of_isolates(disease_subnet))
print("Number of self loops:", nx.number_of_selfloops(disease_subnet))
print("Average clustering coefficient:", nx.average_clustering(disease_subnet))
print("Network density:", nx.density(disease_subnet))
# Out:
# Number of nodes: 31
# Number of edges: 64
# Number of connected components: 8
# Network modularity: 0.0
# Number of isolated nodes: 7
# Number of self loops: 0
# Average clustering coefficient: 0.36083531164176325
# Network density: 0.13763440860215054

# %%
# Find the top five nodes with highest centralities [takes long time]
degree_centrality = nx.degree_centrality(disease_subnet)
betweenness_centrality = nx.betweenness_centrality(disease_subnet)
closeness_centrality = nx.closeness_centrality(disease_subnet)

centrality_table = pd.DataFrame({"Degree centrality" : pd.Series(degree_centrality),
                                    "Betweenness" : pd.Series(betweenness_centrality),
                                    "Closeness centrality" : pd.Series(closeness_centrality)})

print(centrality_table.sort_values(by = "Degree centrality", ascending = False)[0:5].index.values)
print(centrality_table.sort_values(by = "Betweenness", ascending = False)[0:5].index.values)
print(centrality_table.sort_values(by = "Closeness centrality", ascending = False)[0:5].index.values)
# Out:
# ['KRAS' 'EGFR' 'FGFR2' 'NOTCH1' 'IGF1R']
# ['KRAS' 'TTN' 'EGFR' 'PLK1' 'IGF1R']
# ['KRAS' 'EGFR' 'NOTCH1' 'FGFR2' 'IGF1R']

# %% [markdown]
# ### Part C
# - Are all the disease genes connected in the human interactome? If not, use Steiner tree to identify additional genes that may be required to connect the disconnected disease genes, if any.
# - Extract sub-network from the human interactome consisting of the known disease genes and the additional genes identified from Steiner tree. These total set of genes will henceforth be called the extended disease gene list.

# %%
disease_steiner_tree = steiner_tree(STRING_PPI, terminal_nodes = disease_genes, method = "mehlhorn")

# %%
disease_steiner_tree_pos = nx.spring_layout(disease_steiner_tree, seed = 20)
nx.draw(disease_steiner_tree, with_labels = False, pos = disease_steiner_tree_pos, node_size = 80, node_color = "blue", edge_color = "black", width = 0.5)
nx.draw_networkx_nodes(disease_steiner_tree, disease_steiner_tree_pos, nodelist = disease_subnet.nodes(), node_size = 100, node_color = "red")

# %%
# Extract the sub-network of the extended disease gene list
disease_steiner_subnet = STRING_PPI.subgraph(disease_steiner_tree.nodes())
disease_steiner_subnet_pos = nx.spring_layout(disease_steiner_subnet, seed = 20)
nx.draw(disease_steiner_subnet, with_labels = False, pos = disease_steiner_subnet_pos, node_size = 10, node_color = "blue", width = 0.5)
nx.draw_networkx_nodes(disease_steiner_subnet, disease_steiner_subnet_pos, nodelist = disease_subnet.nodes(), node_size = 10, node_color = "red")

# %%
print("Number of genes in extended list: ", disease_steiner_subnet.number_of_nodes())
# Out:
# Number of genes in extended list:  38

# %%
# Get basic properties of the network
print("Number of nodes:", disease_steiner_subnet.number_of_nodes())
print("Number of edges:", disease_steiner_subnet.number_of_edges())
print("Number of connected components:", nx.number_connected_components(disease_steiner_subnet))
print("Network modularity:", nx.algorithms.community.modularity(disease_steiner_subnet, nx.connected_components(disease_steiner_subnet)))
print("Number of isolated nodes:", nx.number_of_isolates(disease_steiner_subnet))
print("Number of self loops:", nx.number_of_selfloops(disease_steiner_subnet))
print("Diameter of network:", nx.diameter(disease_steiner_subnet))
print("Average clustering coefficient:", nx.average_clustering(disease_steiner_subnet))
print("Average shortest path length:", nx.average_shortest_path_length(disease_steiner_subnet))
print("Network density:", nx.density(disease_steiner_subnet))
# Out:
# Number of nodes: 38
# Number of edges: 137
# Number of connected components: 1
# Network modularity: 0.0
# Number of isolated nodes: 0
# Number of self loops: 0
# Diameter of network: 5
# Average clustering coefficient: 0.4671843421456424
# Average shortest path length: 2.2972972972972974
# Network density: 0.19487908961593173

# %% [markdown]
# ### Part D
# - Calculate the network separation between the targets of each drug and the disease genes. Based on the separation distance identify which drug would have the most therapeutic effect.
# - Does the drug with highest therapeutic potential change if the proximity is calculated using known disease genes and the extended disease genes?
# - Are the identified drugs currently in use for the disease in question?

# %%
# Read the drug list and their targets
drug_targets = pd.read_csv("Data/Exercise3_Drug_Targets.csv")
print("Number of drugs: ", len(drug_targets["drug_DrugBankID"].unique()))
drug_targets
# Out:
# Number of drugs:  119
#     drug_DrugBankID target_geneSymbol target_DrugBankID  \
# 0           DB00136               VDR         BE0000779
# 1           DB00153               VDR         BE0000779
# 2           DB00153            CACNG1         BE0004902
# 3           DB00184            CHRNA4         BE0000849
# 4           DB00184            CHRNA7         BE0002341
# 5           DB00184            CHRNB2         BE0000850
# 6           DB00184            CHRNA2         BE0000738
# 7           DB00184            CHRNA9         BE0002343
# 8           DB00184           CHRNA10         BE0000411
# 9           DB00184           CYP19A1         BE0002090
# 10          DB00184              CHAT         BE0000519
# 11          DB00188             PSMB5         BE0002348
# 12          DB00188             PSMB1         BE0002347
# 13          DB00203             PDE5A         BE0000182
# 14          DB00203              ODC1         BE0000404
# 15          DB00203             CD274         BE0003441
# 16          DB00277            ADORA1         BE0000013
# 17          DB00277           ADORA2A         BE0000924
# 18          DB00277           ADORA2B         BE0000241
# 19          DB00277             PDE4B         BE0000487
# 20          DB00277             PDE5A         BE0000182
# 21          DB00277             PDE4A         BE0001133
# 22          DB00277             PDE3A         BE0000436
# 23          DB00277             HDAC2         BE0002366
# 24          DB00277             PARP1         BE0001717
# 25          DB00281            SCN10A         BE0000177
# 26          DB00281             SCN9A         BE0001143
# 27          DB00281             SCN5A         BE0000197
# 28          DB00281              EGFR         BE0000767
# 29          DB00281             SCN4A         BE0002083
# 30          DB00281              ORM1         BE0000925
# 31          DB00297            SCN10A         BE0000177
# 32          DB00297            PTGER1         BE0000064
# 33          DB00307              RXRA         BE0000412
# 34          DB00307              RXRB         BE0000078
# 35          DB00307              RXRG         BE0000707
# 36          DB00313             HDAC9         BE0000881
# 37          DB00313            ACADSB         BE0000573
# 38          DB00313              OGDH         BE0000162
# 39          DB00313           ALDH5A1         BE0000152
# 40          DB00313             SCN1A         BE0004901
# 41          DB00313             HDAC2         BE0002366
# 42          DB00313             PPARA         BE0000071
# 43          DB00313             PPARD         BE0001007
# 44          DB00313             PPARG         BE0000215
# 45          DB00313             HDAC1         BE0008667
# 46          DB00313               HGF         BE0001121
# 47          DB00313              ODC1         BE0000404
# 48          DB00313             CD274         BE0003441
# 49          DB00316             PTGS2         BE0000262
# 50          DB00316             PTGS1         BE0000017
# 51          DB00316            PTGES3         BE0002480
# 52          DB00316             TRPV1         BE0001023
# 53          DB00317              EGFR         BE0000767
# 54          DB00390            ATP1A1         BE0000732
# 55          DB00398              BRAF         BE0000634
# 56          DB00398              RAF1         BE0000036
# 57          DB00398              FLT4         BE0000023
# 58          DB00398               KDR         BE0000369
# 59          DB00398              FLT3         BE0000147
# 60          DB00398            PDGFRB         BE0000205
# 61          DB00398               KIT         BE0000453
# 62          DB00398             FGFR1         BE0002131
# 63          DB00398               RET         BE0002411
# 64          DB00398              FLT1         BE0000029
# 65          DB00399              FDPS         BE0000776
# 66          DB00441              RRM1         BE0000325
# 67          DB00441              TYMS         BE0000324
# 68          DB00441              CMPK         BE0000637
# 69          DB00480           TNFSF11         BE0003517
# 70          DB00480              CDH5         BE0003403
# 71          DB00480             PTGS2         BE0000262
# 72          DB00482             PTGS2         BE0000262
# 73          DB00482               CA2         BE0000322
# 74          DB00482             PDPK1         BE0001193
# 75          DB00482              NEU1         BE0000914
# 76          DB00530             NR1I2         BE0000956
# 77          DB00530              EGFR         BE0000767
# 78          DB00533             PTGS2         BE0000262
# 79          DB00533               ELN         BE0001046
# 80          DB00544              TYMS         BE0000324
# 81          DB00633            ADRA2A         BE0000289
# 82          DB00635             NR3C1         BE0000794
# 83          DB00641             HMGCR         BE0000574
# 84          DB00641             ITGAL         BE0000516
# 85          DB00641             HDAC2         BE0002366
# 86          DB00642              TYMS         BE0000324
# 87          DB00642              ATIC         BE0001240
# 88          DB00642              DHFR         BE0000330
# 89          DB00642              GART         BE0000882
# 90          DB00668            ADRA1A         BE0000501
# 91          DB00668            ADRA1B         BE0000575
# 92          DB00668             ADRB1         BE0000172
# 93          DB00668             ADRB2         BE0000694
# 94          DB00668            ADRA2A         BE0000289
# 95          DB00668            ADRA2B         BE0000572
# 96          DB00668            ADRA1D         BE0000715
# 97          DB00668               TNF         BE0000704
# 98          DB00673             TACR1         BE0000384
# 99          DB00683            GABRA1         BE0004797
# 100         DB00683            GABRA1         BE0008668
# 101         DB00710              FDPS         BE0000776
# 102         DB00712             PTGS2         BE0000262
# 103         DB00712             PTGS1         BE0000017
# 104         DB00724              TLR7         BE0000155
# 105         DB00724              TLR8         BE0003518
# 106         DB00727              NPR1         BE0000556
# 107         DB00744             ALOX5         BE0000248
# 108         DB00745            SLC6A3         BE0000647
# 109         DB00745            ADRA1B         BE0000575
# 110         DB00755              RXRB         BE0000078
# 111         DB00755              RXRG         BE0000707
# 112         DB00755              RARG         BE0000144
# 113         DB00755           ALDH1A1         BE0000554
# 114         DB00755            GPRC5A         BE0000697
# 115         DB00755           ALDH1A2         BE0000513
# 116         DB00755           RARRES1         BE0000653
# 117         DB00755              RARA         BE0000663
# 118         DB00755              RARB         BE0000206
# 119         DB00755              RBP4         BE0000314
# 120         DB00755              RXRA         BE0000412
# 121         DB00755           CYP26A1         BE0003480
# 122         DB00773             TOP2A         BE0000742
# 123         DB00773             TOP2B         BE0002425
# 124         DB00806           ADORA2A         BE0000924
# 125         DB00806            ADORA1         BE0000013
# 126         DB00806              NT5E         BE0001096
# 127         DB00818            GABRB2         BE0002346
# 128         DB00818            GABRB3         BE0002345
# 129         DB00818            GABRA1         BE0004797
# 130         DB00818             SCN4A         BE0002083
# 131         DB00818             SCN2A         BE0002081
# 132         DB00819               CA1         BE0000267
# 133         DB00819               CA2         BE0000322
# 134         DB00819               CA4         BE0000535
# 135         DB00819              CA12         BE0001653
# 136         DB00819              AQP1         BE0000880
# 137         DB00822               DBH         BE0000138
# 138         DB00822             ALDH2         BE0000133
# 139         DB00834               PGR         BE0000557
# 140         DB00834             NR3C1         BE0000794
# 141         DB00834             NR1I2         BE0000956
# 142         DB00877             FRAP1         BE0002386
# 143         DB00927              HRH2         BE0000112
# 144         DB00928             DNMT1         BE0000892
# 145         DB00945             PTGS1         BE0000017
# 146         DB00945             PTGS2         BE0000262
# 147         DB00945            AKR1C1         BE0000126
# 148         DB00945            PRKAA1         BE0004907
# 149         DB00945             EDNRA         BE0000521
# 150         DB00945              TP53         BE0003380
# 151         DB00945             HSPA5         BE0001098
# 152         DB00945            NFKBIA         BE0003469
# 153         DB00945             CASP1         BE0000444
# 154         DB00945             CASP3         BE0001162
# 155         DB00945             IKBKB         BE0001154
# 156         DB00945             MAPK1         BE0009668
# 157         DB00945             CCND1         BE0001027
# 158         DB00945              NEU1         BE0000914
# 159         DB00947              ESR1         BE0000123
# 160         DB00959             NR3C1         BE0000794
# 161         DB00959             ANXA1         BE0000422
# 162         DB00967              HRH1         BE0000442
# 163         DB00982              RARG         BE0000144
# 164         DB00982              RARA         BE0000663
# 165         DB00990           CYP19A1         BE0002090
# 166         DB00997             TOP2A         BE0000742
# 167         DB00997              TOP1         BE0000971
# 168         DB00997             TOP2B         BE0002425
# 169         DB01005              RRM1         BE0000325
# 170         DB01006           CYP19A1         BE0002090
# 171         DB01030              TOP1         BE0000971
# 172         DB01030            TOP1MT         BE0000091
# 173         DB01041              ORM1         BE0004879
# 174         DB01065            MTNR1A         BE0000515
# 175         DB01065            MTNR1B         BE0000327
# 176         DB01065              ESR1         BE0000123
# 177         DB01065             CALM1         BE0000418
# 178         DB01065               MPO         BE0001075
# 179         DB01065              CALR         BE0002109
# 180         DB01065              NQO2         BE0000220
# 181         DB01088             PTGIR         BE0000475
# 182         DB01088            PTGER1         BE0000064
# 183         DB01088             PDE4A         BE0001133
# 184         DB01088             PDE4B         BE0000487
# 185         DB01088             PDE4C         BE0002353
# 186         DB01088             PDE4D         BE0001287
# 187         DB01088              PLAT         BE0001088
# 188         DB01101              TYMS         BE0000324
# 189         DB01216            SRD5A2         BE0000585
# 190         DB01216            SRD5A1         BE0000539
# 191         DB01221            GRIN3A         BE0000641
# 192         DB01221             HTR3A         BE0000311
# 193         DB01221          CHRFAM7A         BE0003438
# 194         DB01221              BCHE         BE0002180
# 195         DB01221              NOS1         BE0000067
# 196         DB01221             TACR1         BE0000384
# 197         DB01221              DRD2         BE0000756
# 198         DB01221             OPRD1         BE0000420
# 199         DB01221            SLC6A2         BE0000486
# 200         DB01221             OPRK1         BE0000632
# 201         DB01221             OPRM1         BE0000770
# 202         DB01221             CHRM1         BE0004890
# 203         DB01221             HTR2A         BE0004957
# 204         DB01221             HTR1A         BE0004958
# 205         DB01222             NR3C1         BE0000794
# 206         DB01222             ANXA1         BE0000422
# 207         DB01229             TUBB1         BE0000026
# 208         DB01229              BCL2         BE0000246
# 209         DB01229              MAP4         BE0003475
# 210         DB01229              MAP2         BE0001100
# 211         DB01229              MAPT         BE0003474
# 212         DB01229             NR1I2         BE0000956
# 213         DB01234             NR3C1         BE0000794
# 214         DB01234             NR0B1         BE0000074
# 215         DB01234             ANXA1         BE0000422
# 216         DB01234             NOS2A         BE0000005
# 217         DB01234             NR1I2         BE0000956
# 218         DB01254              ABL1         BE0000014
# 219         DB01254               SRC         BE0000838
# 220         DB01254             EPHA2         BE0000841
# 221         DB01254               LCK         BE0000842
# 222         DB01254              YES1         BE0000840
# 223         DB01254               KIT         BE0000453
# 224         DB01254            PDGFRB         BE0000205
# 225         DB01254            STAT5B         BE0000891
# 226         DB01254              ABL2         BE0000435
# 227         DB01254               FYN         BE0000839
# 228         DB01254               BTK         BE0001284
# 229         DB01254               CSK         BE0001356
# 230         DB01254             EPHB4         BE0002453
# 231         DB01254            MAPK14         BE0001019
# 232         DB01254              PPAT         BE0000374
# 233         DB01259              EGFR         BE0000767
# 234         DB01259             ERBB2         BE0000511
# 235         DB01262             DNMT1         BE0000892
# 236         DB01262             HDAC1         BE0008667
# 237         DB01268            PDGFRB         BE0000205
# 238         DB01268              FLT1         BE0000029
# 239         DB01268               KIT         BE0000453
# 240         DB01268               KDR         BE0000369
# 241         DB01268              FLT4         BE0000023
# 242         DB01268              FLT3         BE0000147
# 243         DB01268             CSF1R         BE0000853
# 244         DB01268            PDGFRA         BE0000852
# 245         DB01268               MET         BE0000915
# 246         DB01590             FRAP1         BE0002386
# 247         DB02546             HDAC1         BE0002365
# 248         DB02546             HDAC2         BE0002366
# 249         DB02546             HDAC3         BE0002367
# 250         DB02546             HDAC6         BE0002368
# 251         DB02546             HDAC8         BE0001608
# 252         DB02546             HDAC1         BE0008667
# 253         DB04845             TUBB3         BE0001415
# 254         DB04849               KDR         BE0000369
# 255         DB05015             HDAC1         BE0008667
# 256         DB05239            MAP2K1         BE0000870
# 257         DB05294              VEGF         BE0000163
# 258         DB05294              EGFR         BE0000767
# 259         DB05294               TEK         BE0003379
# 260         DB05294               RET         BE0002411
# 261         DB06013             TOP2A         BE0000742
# 262         DB06287             FRAP1         BE0002386
# 263         DB06413            SLC6A3         BE0000647
# 264         DB06589              FLT1         BE0000029
# 265         DB06589               KDR         BE0000369
# 266         DB06589              FLT4         BE0000023
# 267         DB06589            PDGFRA         BE0000852
# 268         DB06589            PDGFRB         BE0000205
# 269         DB06589               KIT         BE0000453
# 270         DB06589             FGFR3         BE0002133
# 271         DB06589               ITK         BE0001341
# 272         DB06589              FGF1         BE0000689
# 273         DB06603             HDAC1         BE0008667
# 274         DB06616              ABL1         BE0000014
# 275         DB06616               HCK         BE0001424
# 276         DB06616               SRC         BE0000838
# 277         DB06616        CDK2deltaT         BE0001072
# 278         DB06616            MAP2K1         BE0000870
# 279         DB06626              FLT1         BE0000029
# 280         DB06626               KDR         BE0000369
# 281         DB06626              FLT4         BE0000023
# 282         DB06772            TUBA4A         BE0001391
# 283         DB06772             TUBB1         BE0000026
# 284         DB06813              DHFR         BE0000330
# 285         DB06813              TYMS         BE0000324
# 286         DB06813              FPGS         BE0000700
# 287         DB08865               ALK         BE0000359
# 288         DB08865               MET         BE0000915
# 289         DB08871              BCL2         BE0000246
# 290         DB08871             TUBB1         BE0000026
# 291         DB08875               MET         BE0000915
# 292         DB08875               KDR         BE0000369
# 293         DB08875               RET         BE0002411
# 294         DB08877              JAK2         BE0002408
# 295         DB08877              JAK3         BE0003493
# 296         DB08881              BRAF         BE0000634
# 297         DB08882              DPP4         BE0000854
# 298         DB08896              FLT1         BE0000029
# 299         DB08896               KDR         BE0000369
# 300         DB08896              FLT4         BE0000023
# 301         DB08896               KIT         BE0000453
# 302         DB08896            PDGFRA         BE0000852
# 303         DB08896            PDGFRB         BE0000205
# 304         DB08896             FGFR1         BE0002131
# 305         DB08896             FGFR2         BE0000748
# 306         DB08896               TEK         BE0003379
# 307         DB08896             NTRK1         BE0001039
# 308         DB08896             EPHA2         BE0000841
# 309         DB08896              RAF1         BE0000036
# 310         DB08896              BRAF         BE0000634
# 311         DB08896            MAPK11         BE0003390
# 312         DB08896              ABL1         BE0000014
# 313         DB08896               RET         BE0002411
# 314         DB08901              ABL1         BE0000014
# 315         DB08901               KIT         BE0000453
# 316         DB08901               RET         BE0002411
# 317         DB08901               TEK         BE0003379
# 318         DB08901              FLT3         BE0000147
# 319         DB08901             FGFR1         BE0002131
# 320         DB08901             FGFR2         BE0000748
# 321         DB08901             FGFR3         BE0002133
# 322         DB08901             FGFR4         BE0001203
# 323         DB08901               LCK         BE0000842
# 324         DB08901               SRC         BE0000838
# 325         DB08901               KDR         BE0000369
# 326         DB08901            PDGFRA         BE0000852
# 327         DB08910               TNF         BE0000704
# 328         DB08910             PTGS2         BE0000262
# 329         DB08912              BRAF         BE0000634
# 330         DB08912              RAF1         BE0000036
# 331         DB08916              EGFR         BE0000767
# 332         DB08916             ERBB2         BE0000511
# 333         DB09049             OPRM1         BE0000770
# 334         DB09053               BTK         BE0001284
# 335         DB09061              CNR1         BE0000061
# 336         DB09061              CNR2         BE0000095
# 337         DB09061             GLRA1         BE0000433
# 338         DB09061             GLRA1         BE0004857
# 339         DB09061             GLRA3         BE0000414
# 340         DB09061             GPR18         BE0002304
# 341         DB09061             HTR1A         BE0000291
# 342         DB09061             HTR2A         BE0000451
# 343         DB09061            CHRNA7         BE0002341
# 344         DB09061             OPRD1         BE0000420
# 345         DB09061             OPRM1         BE0000770
# 346         DB09061             PPARG         BE0000215
# 347         DB09061             TRPV1         BE0001023
# 348         DB09061           CACNA1G         BE0000483
# 349         DB09061           CACNA1H         BE0000864
# 350         DB09061           CACNA1I         BE0000012
# 351         DB09061             TRPA1         BE0001122
# 352         DB09061             TRPM8         BE0001186
# 353         DB09061             TRPV3         BE0003416
# 354         DB09061             VDAC1         BE0002468
# 355         DB09061             HTR3A         BE0000311
# 356         DB09061            ADORA1         BE0000013
# 357         DB09061             PTGS1         BE0000017
# 358         DB09061             PTGS2         BE0000262
# 359         DB09061             ACAT1         BE0000069
# 360         DB09061           CYP17A1         BE0000344
# 361         DB09061             HMGCR         BE0000574
# 362         DB09061               GSR         BE0000648
# 363         DB09061              GPX1         BE0000816
# 364         DB09061              INDO         BE0000693
# 365         DB09061            CYP1B1         BE0001111
# 366         DB09061              NQO1         BE0001184
# 367         DB09061               CAT         BE0001207
# 368         DB09061            CYP3A5         BE0002362
# 369         DB09061            CYP2D6         BE0002363
# 370         DB09061              SOD1         BE0002390
# 371         DB09061            CYP1A2         BE0002433
# 372         DB09063               ALK         BE0000359
# 373         DB09065            CYP3A4         BE0002638
# 374         DB09073              CDK4         BE0002216
# 375         DB09073              CDK6         BE0002212
# 376         DB09074             PARP1         BE0001717
# 377         DB09074            AKR1C3         BE0000592
# 378         DB09078              FLT1         BE0000029
# 379         DB09078               KDR         BE0000369
# 380         DB09078              FLT4         BE0000023
# 381         DB09078             FGFR1         BE0002131
# 382         DB09078             FGFR2         BE0000748
# 383         DB09078             FGFR3         BE0002133
# 384         DB09078             FGFR4         BE0001203
# 385         DB09078            PDGFRA         BE0000852
# 386         DB09078               RET         BE0002411
# 387         DB09078               KIT         BE0000453
# 388         DB09079              FLT1         BE0000029
# 389         DB09079               KDR         BE0000369
# 390         DB09079              FLT4         BE0000023
# 391         DB09079            PDGFRA         BE0000852
# 392         DB09079            PDGFRB         BE0000205
# 393         DB09079             FGFR1         BE0002131
# 394         DB09079             FGFR2         BE0000748
# 395         DB09079             FGFR3         BE0002133
# 396         DB09079              FLT3         BE0000147
# 397         DB09079               LCK         BE0000842
# 398         DB09079               SRC         BE0000838
# 399         DB09330              EGFR         BE0000767
# 400         DB11363               ALK         BE0000359
# 401         DB11581              BCL2         BE0000246
# 402         DB11703               BTK         BE0001284
# 403         DB11718              BRAF         BE0000634
# 404         DB11718             CCND1         BE0001027
# 405         DB11793             PARP1         BE0001717
# 406         DB11800              FLT1         BE0000029
# 407         DB11800               KDR         BE0000369
# 408         DB11800              FLT4         BE0000023
# 409         DB11800               KIT         BE0000453
# 410         DB11800            PDGFRB         BE0000205
# 411         DB11800              FLT3         BE0000147
# 412         DB11800            PDGFRA         BE0000852
# 413         DB11800               TEK         BE0003379
# 414         DB11800             FGFR1         BE0002131
# 415         DB11800               MET         BE0000915
# 416         DB11967            MAP3K1         BE0003430
# 417         DB11967               IL6         BE0000918
# 418         DB11967               TNF         BE0000704
# 419         DB11967              IL1B         BE0001051
# 420         DB11986             NTRK1         BE0001039
# 421         DB11986              JAK2         BE0002408
# 422         DB11986              TNK2         BE0000772
# 423         DB12001              CDK4         BE0002216
# 424         DB12001              CDK6         BE0002212
# 425         DB12130               ALK         BE0000359
# 426         DB12147             FGFR1         BE0002131
# 427         DB12147             FGFR2         BE0000748
# 428         DB12147             FGFR3         BE0002133
# 429         DB12147             FGFR4         BE0001203
# 430         DB12147               RET         BE0001104
# 431         DB12147             CSF1R         BE0000853
# 432         DB12147            PDGFRA         BE0000852
# 433         DB12147            PDGFRB         BE0000205
# 434         DB12147               KIT         BE0000453
# 435         DB12147               KDR         BE0000369
# 436         DB12267               ALK         BE0000359
# 437         DB12267              EGFR         BE0000767
# 438         DB12267              ABL1         BE0000014
# 439         DB12267             IGF1R         BE0000858
# 440         DB12267              FLT3         BE0000147
# 441         DB12267              INSR         BE0000033
# 442         DB12267               MET         BE0000915
# 443         DB12267             ERBB2         BE0000511
# 444         DB14509             IMPA2         BE0000983
# 445         DB14509             IMPA1         BE0001152
# 446         DB14509             GSK3B         BE0001065
# 447         DB14509             GRIA3         BE0000831
# 448         DB14904            MAP2K1         BE0010124
# 449         DB15685               RET         BE0002411
# 450         DB15685              FLT1         BE0000029
# 451         DB15685              FLT4         BE0000023
# 452         DB15685             FGFR1         BE0002131
# 453         DB15685             FGFR2         BE0000748
# 454         DB15685             FGFR3         BE0002133
#
#                                            target_name organisms  \
# 0                                  Vitamin D3 receptor    Humans
# 1                                  Vitamin D3 receptor    Humans
# 2                    Voltage-dependent calcium channel    Humans
# 3      Neuronal acetylcholine receptor subunit alpha-4    Humans
# 4      Neuronal acetylcholine receptor subunit alpha-7    Humans
# 5       Neuronal acetylcholine receptor subunit beta-2    Humans
# 6      Neuronal acetylcholine receptor subunit alpha-2    Humans
# 7      Neuronal acetylcholine receptor subunit alpha-9    Humans
# 8     Neuronal acetylcholine receptor subunit alpha-10    Humans
# 9                                 Cytochrome P450 19A1    Humans
# 10                         Choline O-acetyltransferase    Humans
# 11                      Proteasome subunit beta type-5    Humans
# 12                      Proteasome subunit beta type-1    Humans
# 13        cGMP-specific 3',5'-cyclic phosphodiesterase    Humans
# 14                             Ornithine decarboxylase    Humans
# 15                    Programmed cell death 1 ligand 1    Humans
# 16                               Adenosine receptor A1    Humans
# 17                              Adenosine receptor A2a    Humans
# 18                              Adenosine receptor A2b    Humans
# 19     cAMP-specific 3',5'-cyclic phosphodiesterase 4B    Humans
# 20        cGMP-specific 3',5'-cyclic phosphodiesterase    Humans
# 21     cAMP-specific 3',5'-cyclic phosphodiesterase 4A    Humans
# 22     cGMP-inhibited 3',5'-cyclic phosphodiesterase A    Humans
# 23                               Histone deacetylase 2    Humans
# 24                      Poly [ADP-ribose] polymerase 1    Humans
# 25        Sodium channel protein type 10 subunit alpha    Humans
# 26         Sodium channel protein type 9 subunit alpha    Humans
# 27         Sodium channel protein type 5 subunit alpha    Humans
# 28                    Epidermal growth factor receptor    Humans
# 29         Sodium channel protein type 4 subunit alpha    Humans
# 30                         Alpha-1-acid glycoprotein 1    Humans
# 31        Sodium channel protein type 10 subunit alpha    Humans
# 32               Prostaglandin E2 receptor EP1 subtype    Humans
# 33                    Retinoic acid receptor RXR-alpha    Humans
# 34                     Retinoic acid receptor RXR-beta    Humans
# 35                    Retinoic acid receptor RXR-gamma    Humans
# 36                               Histone deacetylase 9    Humans
# 37   Short/branched chain specific acyl-CoA dehydro...    Humans
# 38         2-oxoglutarate dehydrogenase, mitochondrial    Humans
# 39   Succinate-semialdehyde dehydrogenase, mitochon...    Humans
# 40                              Sodium channel protein    Humans
# 41                               Histone deacetylase 2    Humans
# 42    Peroxisome proliferator-activated receptor alpha    Humans
# 43    Peroxisome proliferator-activated receptor delta    Humans
# 44    Peroxisome proliferator-activated receptor gamma    Humans
# 45                                 Histone deacetylase    Humans
# 46                            Hepatocyte growth factor    Humans
# 47                             Ornithine decarboxylase    Humans
# 48                    Programmed cell death 1 ligand 1    Humans
# 49                        Prostaglandin G/H synthase 2    Humans
# 50                        Prostaglandin G/H synthase 1    Humans
# 51                          Prostaglandin E synthase 3    Humans
# 52   Transient receptor potential cation channel su...    Humans
# 53                    Epidermal growth factor receptor    Humans
# 54   Sodium/potassium-transporting ATPase subunit a...    Humans
# 55               Serine/threonine-protein kinase B-raf    Humans
# 56   RAF proto-oncogene serine/threonine-protein ki...    Humans
# 57       Vascular endothelial growth factor receptor 3    Humans
# 58       Vascular endothelial growth factor receptor 2    Humans
# 59          Receptor-type tyrosine-protein kinase FLT3    Humans
# 60        Platelet-derived growth factor receptor beta    Humans
# 61           Mast/stem cell growth factor receptor Kit    Humans
# 62                 Fibroblast growth factor receptor 1    Humans
# 63   Proto-oncogene tyrosine-protein kinase recepto...    Humans
# 64       Vascular endothelial growth factor receptor 1    Humans
# 65                     Farnesyl pyrophosphate synthase    Humans
# 66   Ribonucleoside-diphosphate reductase large sub...    Humans
# 67                                Thymidylate synthase    Humans
# 68                                      UMP-CMP kinase    Humans
# 69   Tumor necrosis factor ligand superfamily membe...    Humans
# 70                                          Cadherin-5    Humans
# 71                        Prostaglandin G/H synthase 2    Humans
# 72                        Prostaglandin G/H synthase 2    Humans
# 73                                Carbonic anhydrase 2    Humans
# 74       3-phosphoinositide-dependent protein kinase 1    Humans
# 75                                         Sialidase-1    Humans
# 76       Nuclear receptor subfamily 1 group I member 2    Humans
# 77                    Epidermal growth factor receptor    Humans
# 78                        Prostaglandin G/H synthase 2    Humans
# 79                                             Elastin    Humans
# 80                                Thymidylate synthase    Humans
# 81                        Alpha-2A adrenergic receptor    Humans
# 82                             Glucocorticoid receptor    Humans
# 83     3-hydroxy-3-methylglutaryl-coenzyme A reductase    Humans
# 84                                    Integrin alpha-L    Humans
# 85                               Histone deacetylase 2    Humans
# 86                                Thymidylate synthase    Humans
# 87       Bifunctional purine biosynthesis protein PURH    Humans
# 88                             Dihydrofolate reductase    Humans
# 89   Trifunctional purine biosynthetic protein aden...    Humans
# 90                        Alpha-1A adrenergic receptor    Humans
# 91                        Alpha-1B adrenergic receptor    Humans
# 92                          Beta-1 adrenergic receptor    Humans
# 93                          Beta-2 adrenergic receptor    Humans
# 94                        Alpha-2A adrenergic receptor    Humans
# 95                        Alpha-2B adrenergic receptor    Humans
# 96                        Alpha-1D adrenergic receptor    Humans
# 97                               Tumor necrosis factor    Humans
# 98                               Neurokinin 1 receptor    Humans
# 99                                    GABA(A) Receptor    Humans
# 100       GABA(A) Receptor Benzodiazepine Binding Site    Humans
# 101                    Farnesyl pyrophosphate synthase    Humans
# 102                       Prostaglandin G/H synthase 2    Humans
# 103                       Prostaglandin G/H synthase 1    Humans
# 104                               Toll-like receptor 7    Humans
# 105                               Toll-like receptor 8    Humans
# 106              Atrial natriuretic peptide receptor 1    Humans
# 107                        Arachidonate 5-lipoxygenase    Humans
# 108              Sodium-dependent dopamine transporter    Humans
# 109                       Alpha-1B adrenergic receptor    Humans
# 110                    Retinoic acid receptor RXR-beta    Humans
# 111                   Retinoic acid receptor RXR-gamma    Humans
# 112                       Retinoic acid receptor gamma    Humans
# 113                            Retinal dehydrogenase 1    Humans
# 114                    Retinoic acid-induced protein 3    Humans
# 115                            Retinal dehydrogenase 2    Humans
# 116         Retinoic acid receptor responder protein 1    Humans
# 117                       Retinoic acid receptor alpha    Humans
# 118                        Retinoic acid receptor beta    Humans
# 119                          Retinol-binding protein 4    Humans
# 120                   Retinoic acid receptor RXR-alpha    Humans
# 121                               Cytochrome P450 26A1    Humans
# 122                          DNA topoisomerase 2-alpha    Humans
# 123                           DNA topoisomerase 2-beta    Humans
# 124                             Adenosine receptor A2a    Humans
# 125                              Adenosine receptor A1    Humans
# 126                                    5'-nucleotidase    Humans
# 127    Gamma-aminobutyric acid receptor subunit beta-2    Humans
# 128    Gamma-aminobutyric acid receptor subunit beta-3    Humans
# 129                                   GABA(A) Receptor    Humans
# 130        Sodium channel protein type 4 subunit alpha    Humans
# 131        Sodium channel protein type 2 subunit alpha    Humans
# 132                               Carbonic anhydrase 1    Humans
# 133                               Carbonic anhydrase 2    Humans
# 134                               Carbonic anhydrase 4    Humans
# 135                              Carbonic anhydrase 12    Humans
# 136                                        Aquaporin-1    Humans
# 137                          Dopamine beta-hydroxylase    Humans
# 138              Aldehyde dehydrogenase, mitochondrial    Humans
# 139                              Progesterone receptor    Humans
# 140                            Glucocorticoid receptor    Humans
# 141      Nuclear receptor subfamily 1 group I member 2    Humans
# 142               Serine/threonine-protein kinase mTOR    Humans
# 143                              Histamine H2 receptor    Humans
# 144               DNA (cytosine-5)-methyltransferase 1    Humans
# 145                       Prostaglandin G/H synthase 1    Humans
# 146                       Prostaglandin G/H synthase 2    Humans
# 147             Aldo-keto reductase family 1 member C1    Humans
# 148                    5'-AMP-activated protein kinase    Humans
# 149                              Endothelin-1 receptor    Humans
# 150                         Cellular tumor antigen p53    Humans
# 151                   78 kDa glucose-regulated protein    Humans
# 152                         NF-kappa-B inhibitor alpha    Humans
# 153                                          Caspase-1    Humans
# 154                                          Caspase-3    Humans
# 155  Inhibitor of nuclear factor kappa-B kinase sub...    Humans
# 156        Extracellular signal-regulated kinase (ERK)    Humans
# 157                            G1/S-specific cyclin-D1    Humans
# 158                                        Sialidase-1    Humans
# 159                            Estrogen receptor alpha    Humans
# 160                            Glucocorticoid receptor    Humans
# 161                                         Annexin A1    Humans
# 162                              Histamine H1 receptor    Humans
# 163                       Retinoic acid receptor gamma    Humans
# 164                       Retinoic acid receptor alpha    Humans
# 165                               Cytochrome P450 19A1    Humans
# 166                          DNA topoisomerase 2-alpha    Humans
# 167                                DNA topoisomerase 1    Humans
# 168                           DNA topoisomerase 2-beta    Humans
# 169  Ribonucleoside-diphosphate reductase large sub...    Humans
# 170                               Cytochrome P450 19A1    Humans
# 171                                DNA topoisomerase 1    Humans
# 172                 DNA topoisomerase I, mitochondrial    Humans
# 173                           alpha1-acid glycoprotein    Humans
# 174                         Melatonin receptor type 1A    Humans
# 175                         Melatonin receptor type 1B    Humans
# 176                            Estrogen receptor alpha    Humans
# 177                                         Calmodulin    Humans
# 178                                    Myeloperoxidase    Humans
# 179                                       Calreticulin    Humans
# 180  Ribosyldihydronicotinamide dehydrogenase [quin...    Humans
# 181                              Prostacyclin receptor    Humans
# 182              Prostaglandin E2 receptor EP1 subtype    Humans
# 183    cAMP-specific 3',5'-cyclic phosphodiesterase 4A    Humans
# 184    cAMP-specific 3',5'-cyclic phosphodiesterase 4B    Humans
# 185    cAMP-specific 3',5'-cyclic phosphodiesterase 4C    Humans
# 186    cAMP-specific 3',5'-cyclic phosphodiesterase 4D    Humans
# 187                  Tissue-type plasminogen activator    Humans
# 188                               Thymidylate synthase    Humans
# 189            3-oxo-5-alpha-steroid 4-dehydrogenase 2    Humans
# 190            3-oxo-5-alpha-steroid 4-dehydrogenase 1    Humans
# 191             Glutamate receptor ionotropic, NMDA 3A    Humans
# 192                    5-hydroxytryptamine receptor 3A    Humans
# 193     Alpha-7 nicotinic cholinergic receptor subunit    Humans
# 194                                     Cholinesterase    Humans
# 195                       Nitric oxide synthase, brain    Humans
# 196                              Neurokinin 1 receptor    Humans
# 197                               Dopamine D2 receptor    Humans
# 198                         Delta-type opioid receptor    Humans
# 199         Sodium-dependent noradrenaline transporter    Humans
# 200                         Kappa-type opioid receptor    Humans
# 201                            Mu-type opioid receptor    Humans
# 202                  Muscarinic acetylcholine receptor    Humans
# 203                     5-hydroxytryptamine receptor 2    Humans
# 204                     5-hydroxytryptamine receptor 1    Humans
# 205                            Glucocorticoid receptor    Humans
# 206                                         Annexin A1    Humans
# 207                               Tubulin beta-1 chain    Humans
# 208                          Apoptosis regulator Bcl-2    Humans
# 209                   Microtubule-associated protein 4    Humans
# 210                   Microtubule-associated protein 2    Humans
# 211                 Microtubule-associated protein tau    Humans
# 212      Nuclear receptor subfamily 1 group I member 2    Humans
# 213                            Glucocorticoid receptor    Humans
# 214      Nuclear receptor subfamily 0 group B member 1    Humans
# 215                                         Annexin A1    Humans
# 216                   Nitric oxide synthase, inducible    Humans
# 217      Nuclear receptor subfamily 1 group I member 2    Humans
# 218                       Tyrosine-protein kinase ABL1    Humans
# 219         Proto-oncogene tyrosine-protein kinase Src    Humans
# 220                           Ephrin type-A receptor 2    Humans
# 221                        Tyrosine-protein kinase Lck    Humans
# 222                        Tyrosine-protein kinase Yes    Humans
# 223          Mast/stem cell growth factor receptor Kit    Humans
# 224       Platelet-derived growth factor receptor beta    Humans
# 225  Signal transducer and activator of transcripti...    Humans
# 226                  Abelson tyrosine-protein kinase 2    Humans
# 227                        Tyrosine-protein kinase Fyn    Humans
# 228                        Tyrosine-protein kinase BTK    Humans
# 229                        Tyrosine-protein kinase CSK    Humans
# 230                           Ephrin type-B receptor 4    Humans
# 231                Mitogen-activated protein kinase 14    Humans
# 232                     Amidophosphoribosyltransferase    Humans
# 233                   Epidermal growth factor receptor    Humans
# 234            Receptor tyrosine-protein kinase erbB-2    Humans
# 235               DNA (cytosine-5)-methyltransferase 1    Humans
# 236                                Histone deacetylase    Humans
# 237       Platelet-derived growth factor receptor beta    Humans
# 238      Vascular endothelial growth factor receptor 1    Humans
# 239          Mast/stem cell growth factor receptor Kit    Humans
# 240      Vascular endothelial growth factor receptor 2    Humans
# 241      Vascular endothelial growth factor receptor 3    Humans
# 242         Receptor-type tyrosine-protein kinase FLT3    Humans
# 243    Macrophage colony-stimulating factor 1 receptor    Humans
# 244      Platelet-derived growth factor receptor alpha    Humans
# 245                  Hepatocyte growth factor receptor    Humans
# 246               Serine/threonine-protein kinase mTOR    Humans
# 247                              Histone deacetylase 1    Humans
# 248                              Histone deacetylase 2    Humans
# 249                              Histone deacetylase 3    Humans
# 250                              Histone deacetylase 6    Humans
# 251                              Histone deacetylase 8    Humans
# 252                                Histone deacetylase    Humans
# 253                               Tubulin beta-3 chain    Humans
# 254      Vascular endothelial growth factor receptor 2    Humans
# 255                                Histone deacetylase    Humans
# 256  Dual specificity mitogen-activated protein kin...    Humans
# 257               Vascular endothelial growth factor A    Humans
# 258                   Epidermal growth factor receptor    Humans
# 259                            Angiopoietin-1 receptor    Humans
# 260  Proto-oncogene tyrosine-protein kinase recepto...    Humans
# 261                          DNA topoisomerase 2-alpha    Humans
# 262               Serine/threonine-protein kinase mTOR    Humans
# 263              Sodium-dependent dopamine transporter    Humans
# 264      Vascular endothelial growth factor receptor 1    Humans
# 265      Vascular endothelial growth factor receptor 2    Humans
# 266      Vascular endothelial growth factor receptor 3    Humans
# 267      Platelet-derived growth factor receptor alpha    Humans
# 268       Platelet-derived growth factor receptor beta    Humans
# 269          Mast/stem cell growth factor receptor Kit    Humans
# 270                Fibroblast growth factor receptor 3    Humans
# 271                    Tyrosine-protein kinase ITK/TSK    Humans
# 272                         Fibroblast growth factor 1    Humans
# 273                                Histone deacetylase    Humans
# 274                       Tyrosine-protein kinase ABL1    Humans
# 275                        Tyrosine-protein kinase HCK    Humans
# 276         Proto-oncogene tyrosine-protein kinase Src    Humans
# 277                          Cyclin-dependent kinase 2    Humans
# 278  Dual specificity mitogen-activated protein kin...    Humans
# 279      Vascular endothelial growth factor receptor 1    Humans
# 280      Vascular endothelial growth factor receptor 2    Humans
# 281      Vascular endothelial growth factor receptor 3    Humans
# 282                             Tubulin alpha-4A chain    Humans
# 283                               Tubulin beta-1 chain    Humans
# 284                            Dihydrofolate reductase    Humans
# 285                               Thymidylate synthase    Humans
# 286         Folylpolyglutamate synthase, mitochondrial    Humans
# 287                       ALK tyrosine kinase receptor    Humans
# 288                  Hepatocyte growth factor receptor    Humans
# 289                          Apoptosis regulator Bcl-2    Humans
# 290                               Tubulin beta-1 chain    Humans
# 291                  Hepatocyte growth factor receptor    Humans
# 292      Vascular endothelial growth factor receptor 2    Humans
# 293  Proto-oncogene tyrosine-protein kinase recepto...    Humans
# 294                       Tyrosine-protein kinase JAK2    Humans
# 295                       Tyrosine-protein kinase JAK3    Humans
# 296              Serine/threonine-protein kinase B-raf    Humans
# 297                             Dipeptidyl peptidase 4    Humans
# 298      Vascular endothelial growth factor receptor 1    Humans
# 299      Vascular endothelial growth factor receptor 2    Humans
# 300      Vascular endothelial growth factor receptor 3    Humans
# 301          Mast/stem cell growth factor receptor Kit    Humans
# 302      Platelet-derived growth factor receptor alpha    Humans
# 303       Platelet-derived growth factor receptor beta    Humans
# 304                Fibroblast growth factor receptor 1    Humans
# 305                Fibroblast growth factor receptor 2    Humans
# 306                            Angiopoietin-1 receptor    Humans
# 307         High affinity nerve growth factor receptor    Humans
# ...
# 408      Vascular endothelial growth factor receptor 3    Humans
# 409          Mast/stem cell growth factor receptor Kit    Humans
# 410       Platelet-derived growth factor receptor beta    Humans
# 411         Receptor-type tyrosine-protein kinase FLT3    Humans
# 412      Platelet-derived growth factor receptor alpha    Humans
# 413                            Angiopoietin-1 receptor    Humans
# 414                Fibroblast growth factor receptor 1    Humans
# 415                  Hepatocyte growth factor receptor    Humans
# 416   Mitogen-activated protein kinase kinase kinase 1    Humans
# 417                                      Interleukin-6    Humans
# 418                              Tumor necrosis factor    Humans
# 419                                 Interleukin-1 beta    Humans
# 420         High affinity nerve growth factor receptor    Humans
# 421                       Tyrosine-protein kinase JAK2    Humans
# 422                           Activated CDC42 kinase 1    Humans
# 423                          Cyclin-dependent kinase 4    Humans
# 424                          Cyclin-dependent kinase 6    Humans
# 425                       ALK tyrosine kinase receptor    Humans
# 426                Fibroblast growth factor receptor 1    Humans
# 427                Fibroblast growth factor receptor 2    Humans
# 428                Fibroblast growth factor receptor 3    Humans
# 429                Fibroblast growth factor receptor 4    Humans
# 430                                 RET proto-oncogene    Humans
# 431    Macrophage colony-stimulating factor 1 receptor    Humans
# 432      Platelet-derived growth factor receptor alpha    Humans
# 433       Platelet-derived growth factor receptor beta    Humans
# 434          Mast/stem cell growth factor receptor Kit    Humans
# 435      Vascular endothelial growth factor receptor 2    Humans
# 436                       ALK tyrosine kinase receptor    Humans
# 437                   Epidermal growth factor receptor    Humans
# 438                       Tyrosine-protein kinase ABL1    Humans
# 439              Insulin-like growth factor 1 receptor    Humans
# 440         Receptor-type tyrosine-protein kinase FLT3    Humans
# 441                                   Insulin receptor    Humans
# 442                  Hepatocyte growth factor receptor    Humans
# 443            Receptor tyrosine-protein kinase erbB-2    Humans
# 444                         Inositol monophosphatase 2    Humans
# 445                         Inositol monophosphatase 1    Humans
# 446                    Glycogen synthase kinase-3 beta    Humans
# 447                               Glutamate receptor 3    Humans
# 448    Mitogen-activated protein kinase kinase (MAPKK)    Humans
# 449  Proto-oncogene tyrosine-protein kinase recepto...    Humans
# 450      Vascular endothelial growth factor receptor 1    Humans
# 451      Vascular endothelial growth factor receptor 3    Humans
# 452                Fibroblast growth factor receptor 1    Humans
# 453                Fibroblast growth factor receptor 2    Humans
# 454                Fibroblast growth factor receptor 3    Humans
#
#                 drug_name
# 0              Calcitriol
# 1          Ergocalciferol
# 2          Ergocalciferol
# 3                Nicotine
# 4                Nicotine
# 5                Nicotine
# 6                Nicotine
# 7                Nicotine
# 8                Nicotine
# 9                Nicotine
# 10               Nicotine
# 11             Bortezomib
# 12             Bortezomib
# 13             Sildenafil
# 14             Sildenafil
# 15             Sildenafil
# 16           Theophylline
# 17           Theophylline
# 18           Theophylline
# 19           Theophylline
# 20           Theophylline
# 21           Theophylline
# 22           Theophylline
# 23           Theophylline
# 24           Theophylline
# 25              Lidocaine
# 26              Lidocaine
# 27              Lidocaine
# 28              Lidocaine
# 29              Lidocaine
# 30              Lidocaine
# 31            Bupivacaine
# 32            Bupivacaine
# 33             Bexarotene
# 34             Bexarotene
# 35             Bexarotene
# 36          Valproic acid
# 37          Valproic acid
# 38          Valproic acid
# 39          Valproic acid
# 40          Valproic acid
# 41          Valproic acid
# 42          Valproic acid
# 43          Valproic acid
# 44          Valproic acid
# 45          Valproic acid
# 46          Valproic acid
# 47          Valproic acid
# 48          Valproic acid
# 49          Acetaminophen
# 50          Acetaminophen
# 51          Acetaminophen
# 52          Acetaminophen
# 53              Gefitinib
# 54                Digoxin
# 55              Sorafenib
# 56              Sorafenib
# 57              Sorafenib
# 58              Sorafenib
# 59              Sorafenib
# 60              Sorafenib
# 61              Sorafenib
# 62              Sorafenib
# 63              Sorafenib
# 64              Sorafenib
# 65        Zoledronic acid
# 66            Gemcitabine
# 67            Gemcitabine
# 68            Gemcitabine
# 69           Lenalidomide
# 70           Lenalidomide
# 71           Lenalidomide
# 72              Celecoxib
# 73              Celecoxib
# 74              Celecoxib
# 75              Celecoxib
# 76              Erlotinib
# 77              Erlotinib
# 78              Rofecoxib
# 79              Rofecoxib
# 80           Fluorouracil
# 81        Dexmedetomidine
# 82             Prednisone
# 83            Simvastatin
# 84            Simvastatin
# 85            Simvastatin
# 86             Pemetrexed
# 87             Pemetrexed
# 88             Pemetrexed
# 89             Pemetrexed
# 90            Epinephrine
# 91            Epinephrine
# 92            Epinephrine
# 93            Epinephrine
# 94            Epinephrine
# 95            Epinephrine
# 96            Epinephrine
# 97            Epinephrine
# 98             Aprepitant
# 99              Midazolam
# 100             Midazolam
# 101           Ibandronate
# 102          Flurbiprofen
# 103          Flurbiprofen
# 104             Imiquimod
# 105             Imiquimod
# 106         Nitroglycerin
# 107              Zileuton
# 108             Modafinil
# 109             Modafinil
# 110             Tretinoin
# 111             Tretinoin
# 112             Tretinoin
# 113             Tretinoin
# 114             Tretinoin
# 115             Tretinoin
# 116             Tretinoin
# 117             Tretinoin
# 118             Tretinoin
# 119             Tretinoin
# 120             Tretinoin
# 121             Tretinoin
# 122             Etoposide
# 123             Etoposide
# 124        Pentoxifylline
# 125        Pentoxifylline
# 126        Pentoxifylline
# 127              Propofol
# 128              Propofol
# 129              Propofol
# 130              Propofol
# 131              Propofol
# 132         Acetazolamide
# 133         Acetazolamide
# 134         Acetazolamide
# 135         Acetazolamide
# 136         Acetazolamide
# 137            Disulfiram
# 138            Disulfiram
# 139          Mifepristone
# 140          Mifepristone
# 141          Mifepristone
# 142             Sirolimus
# 143            Famotidine
# 144           Azacitidine
# 145  Acetylsalicylic acid
# 146  Acetylsalicylic acid
# 147  Acetylsalicylic acid
# 148  Acetylsalicylic acid
# 149  Acetylsalicylic acid
# 150  Acetylsalicylic acid
# 151  Acetylsalicylic acid
# 152  Acetylsalicylic acid
# 153  Acetylsalicylic acid
# 154  Acetylsalicylic acid
# 155  Acetylsalicylic acid
# 156  Acetylsalicylic acid
# 157  Acetylsalicylic acid
# 158  Acetylsalicylic acid
# 159           Fulvestrant
# 160    Methylprednisolone
# 161    Methylprednisolone
# 162         Desloratadine
# 163          Isotretinoin
# 164          Isotretinoin
# 165            Exemestane
# 166           Doxorubicin
# 167           Doxorubicin
# 168           Doxorubicin
# 169           Hydroxyurea
# 170             Letrozole
# 171             Topotecan
# 172             Topotecan
# 173           Thalidomide
# 174             Melatonin
# 175             Melatonin
# 176             Melatonin
# 177             Melatonin
# 178             Melatonin
# 179             Melatonin
# 180             Melatonin
# 181              Iloprost
# 182              Iloprost
# 183              Iloprost
# 184              Iloprost
# 185              Iloprost
# 186              Iloprost
# 187              Iloprost
# 188          Capecitabine
# 189           Finasteride
# 190           Finasteride
# 191              Ketamine
# 192              Ketamine
# 193              Ketamine
# 194              Ketamine
# 195              Ketamine
# 196              Ketamine
# 197              Ketamine
# 198              Ketamine
# 199              Ketamine
# 200              Ketamine
# 201              Ketamine
# 202              Ketamine
# 203              Ketamine
# 204              Ketamine
# 205            Budesonide
# 206            Budesonide
# 207            Paclitaxel
# 208            Paclitaxel
# 209            Paclitaxel
# 210            Paclitaxel
# 211            Paclitaxel
# 212            Paclitaxel
# 213         Dexamethasone
# 214         Dexamethasone
# 215         Dexamethasone
# 216         Dexamethasone
# 217         Dexamethasone
# 218             Dasatinib
# 219             Dasatinib
# 220             Dasatinib
# 221             Dasatinib
# 222             Dasatinib
# 223             Dasatinib
# 224             Dasatinib
# 225             Dasatinib
# 226             Dasatinib
# 227             Dasatinib
# 228             Dasatinib
# 229             Dasatinib
# 230             Dasatinib
# 231             Dasatinib
# 232             Dasatinib
# 233             Lapatinib
# 234             Lapatinib
# 235            Decitabine
# 236            Decitabine
# 237             Sunitinib
# 238             Sunitinib
# 239             Sunitinib
# 240             Sunitinib
# 241             Sunitinib
# 242             Sunitinib
# 243             Sunitinib
# 244             Sunitinib
# 245             Sunitinib
# 246            Everolimus
# 247            Vorinostat
# 248            Vorinostat
# 249            Vorinostat
# 250            Vorinostat
# 251            Vorinostat
# 252            Vorinostat
# 253           Ixabepilone
# 254             Cediranib
# 255            Belinostat
# 256           Cobimetinib
# 257            Vandetanib
# 258            Vandetanib
# 259            Vandetanib
# 260            Vandetanib
# 261         Aldoxorubicin
# 262          Temsirolimus
# 263           Armodafinil
# 264             Pazopanib
# 265             Pazopanib
# 266             Pazopanib
# 267             Pazopanib
# 268             Pazopanib
# 269             Pazopanib
# 270             Pazopanib
# 271             Pazopanib
# 272             Pazopanib
# 273          Panobinostat
# 274             Bosutinib
# 275             Bosutinib
# 276             Bosutinib
# 277             Bosutinib
# 278             Bosutinib
# 279              Axitinib
# 280              Axitinib
# 281              Axitinib
# 282           Cabazitaxel
# 283           Cabazitaxel
# 284          Pralatrexate
# 285          Pralatrexate
# 286          Pralatrexate
# 287            Crizotinib
# 288            Crizotinib
# 289              Eribulin
# 290              Eribulin
# 291          Cabozantinib
# 292          Cabozantinib
# 293          Cabozantinib
# 294           Ruxolitinib
# 295           Ruxolitinib
# 296           Vemurafenib
# 297           Linagliptin
# 298           Regorafenib
# 299           Regorafenib
# 300           Regorafenib
# 301           Regorafenib
# 302           Regorafenib
# 303           Regorafenib
# 304           Regorafenib
# 305           Regorafenib
# 306           Regorafenib
# 307           Regorafenib
# 308           Regorafenib
# 309           Regorafenib
# 310           Regorafenib
# 311           Regorafenib
# 312           Regorafenib
# 313           Regorafenib
# 314             Ponatinib
# 315             Ponatinib
# 316             Ponatinib
# 317             Ponatinib
# 318             Ponatinib
# 319             Ponatinib
# 320             Ponatinib
# 321             Ponatinib
# 322             Ponatinib
# 323             Ponatinib
# 324             Ponatinib
# 325             Ponatinib
# 326             Ponatinib
# 327          Pomalidomide
# 328          Pomalidomide
# 329            Dabrafenib
# 330            Dabrafenib
# 331              Afatinib
# 332              Afatinib
# 333             Naloxegol
# 334             Ibrutinib
# 335           Cannabidiol
# 336           Cannabidiol
# 337           Cannabidiol
# 338           Cannabidiol
# 339           Cannabidiol
# 340           Cannabidiol
# 341           Cannabidiol
# 342           Cannabidiol
# 343           Cannabidiol
# 344           Cannabidiol
# 345           Cannabidiol
# 346           Cannabidiol
# 347           Cannabidiol
# 348           Cannabidiol
# 349           Cannabidiol
# 350           Cannabidiol
# 351           Cannabidiol
# 352           Cannabidiol
# 353           Cannabidiol
# 354           Cannabidiol
# 355           Cannabidiol
# 356           Cannabidiol
# 357           Cannabidiol
# 358           Cannabidiol
# 359           Cannabidiol
# 360           Cannabidiol
# 361           Cannabidiol
# 362           Cannabidiol
# 363           Cannabidiol
# 364           Cannabidiol
# 365           Cannabidiol
# 366           Cannabidiol
# 367           Cannabidiol
# 368           Cannabidiol
# 369           Cannabidiol
# 370           Cannabidiol
# 371           Cannabidiol
# 372             Ceritinib
# 373            Cobicistat
# 374           Palbociclib
# 375           Palbociclib
# 376              Olaparib
# 377              Olaparib
# 378            Lenvatinib
# 379            Lenvatinib
# 380            Lenvatinib
# 381            Lenvatinib
# 382            Lenvatinib
# 383            Lenvatinib
# 384            Lenvatinib
# 385            Lenvatinib
# 386            Lenvatinib
# 387            Lenvatinib
# 388            Nintedanib
# 389            Nintedanib
# 390            Nintedanib
# 391            Nintedanib
# 392            Nintedanib
# 393            Nintedanib
# 394            Nintedanib
# 395            Nintedanib
# 396            Nintedanib
# 397            Nintedanib
# 398            Nintedanib
# 399           Osimertinib
# 400             Alectinib
# 401            Venetoclax
# 402         Acalabrutinib
# 403           Encorafenib
# 404           Encorafenib
# 405             Niraparib
# 406             Tivozanib
# 407             Tivozanib
# 408             Tivozanib
# 409             Tivozanib
# 410             Tivozanib
# 411             Tivozanib
# 412             Tivozanib
# 413             Tivozanib
# 414             Tivozanib
# 415             Tivozanib
# 416           Binimetinib
# 417           Binimetinib
# 418           Binimetinib
# 419           Binimetinib
# 420           Entrectinib
# 421           Entrectinib
# 422           Entrectinib
# 423           Abemaciclib
# 424           Abemaciclib
# 425            Lorlatinib
# 426           Erdafitinib
# 427           Erdafitinib
# 428           Erdafitinib
# 429           Erdafitinib
# 430           Erdafitinib
# 431           Erdafitinib
# 432           Erdafitinib
# 433           Erdafitinib
# 434           Erdafitinib
# 435           Erdafitinib
# 436            Brigatinib
# 437            Brigatinib
# 438            Brigatinib
# 439            Brigatinib
# 440            Brigatinib
# 441            Brigatinib
# 442            Brigatinib
# 443            Brigatinib
# 444     Lithium carbonate
# 445     Lithium carbonate
# 446     Lithium carbonate
# 447     Lithium carbonate
# 448            Pimasertib
# 449         Selpercatinib
# 450         Selpercatinib
# 451         Selpercatinib
# 452         Selpercatinib
# 453         Selpercatinib
# 454         Selpercatinib

# %%
# Since our search space is PPI, we reduce the drugs to only those that has targets in the network
drug_targets = drug_targets.loc[drug_targets["target_geneSymbol"].isin(STRING_PPI.nodes())]
print("Number of drugs: ", len(drug_targets["drug_DrugBankID"].unique()))
# Out:
# Number of drugs:  115

# %%
# Extract the sub-network of the drug targets
target_subnet = STRING_PPI.subgraph(drug_targets["target_geneSymbol"].unique())
target_subnet_pos = nx.spring_layout(target_subnet, seed = 20)
nx.draw(target_subnet, with_labels = False, pos = target_subnet_pos, node_size = 10, node_color = "green", width = 0.5)

# %%
# Prepare known drug-target associations 
drug2targets = {}
for drug in drug_targets["drug_DrugBankID"].unique(): 
    drug2targets[drug] = [e for e in drug_targets.loc[drug_targets["drug_DrugBankID"] == drug, "target_geneSymbol"]]

# %%
# Remove drugs with one known targets
# This is done since the separation distance calculation formula we used does not allow calculation if there is only one gene
drug2targets = {key: value for key, value in drug2targets.items() if len(np.unique(value)) > 1}

print("Number of drugs: ", len(drug2targets))
# Out:
# Number of drugs:  73

# %%
# Calculate network separation between the targets of known drugs and disease genes
result = pd.DataFrame()
for drug in drug2targets.keys():



    # Using the known disease genes --------
    genes_A = set(disease_subnet.nodes()) & set(STRING_PPI.nodes())
    genes_B = set(drug2targets[drug]) & set(STRING_PPI.nodes())

    d_A = separation.calc_single_set_distance(STRING_PPI,genes_A)
    d_B = separation.calc_single_set_distance(STRING_PPI,genes_B)

    # distances BETWEEN the two gene sets:
    d_AB = separation.calc_set_pair_distances(STRING_PPI,genes_A,genes_B)

    # calculate separation
    s_AB_knownGenes = d_AB - (d_A + d_B)/2



    # Using the extended disease genes --------
    genes_A = set(disease_steiner_subnet.nodes()) & set(STRING_PPI.nodes())
    genes_B = set(drug2targets[drug]) & set(STRING_PPI.nodes())

    d_A = separation.calc_single_set_distance(STRING_PPI,genes_A)
    d_B = separation.calc_single_set_distance(STRING_PPI,genes_B)

    # distances BETWEEN the two gene sets:
    d_AB = separation.calc_set_pair_distances(STRING_PPI,genes_A,genes_B)

    # calculate separation
    s_AB_extendedGenes = d_AB - (d_A + d_B)/2

    
    # Save the results as new row in the datafrma --------
    tmp = pd.DataFrame({"Drug" : drug,
                        "Number of targets" : len(genes_B),
                        "Separation (known)" : s_AB_knownGenes,
                        "Separation (extended)" : s_AB_extendedGenes},
                            index = [0])

    result = pd.concat([result, tmp])
    
result = result.sort_values(by = "Separation (extended)", ascending = True)
result = result.reset_index(drop = True)

# %%
# Get the drug ID to drug name mapping
drugID_2_drugName = drug_targets[["drug_DrugBankID", "drug_name"]].drop_duplicates(keep = "first")
drugID_2_drugName.shape
# Out:
# (115, 2)

# %%
# Add the drug names
result = result.merge(drugID_2_drugName, how = "left", left_on = "Drug", right_on = "drug_DrugBankID")
result
# Out:
#        Drug  Number of targets  Separation (known)  Separation (extended)  \
# 0   DB00530                  2           -0.097752              -0.050000
# 1   DB11986                  3           -0.083491              -0.036585
# 2   DB08871                  2            0.053763               0.100000
# 3   DB08896                 16            0.014756               0.129630
# 4   DB00203                  3            0.063567               0.134146
# 5   DB08865                  2            0.144673               0.175000
# 6   DB01254                 14            0.073605               0.175824
# 7   DB00641                  3            0.092979               0.182927
# 8   DB12267                  8            0.092225               0.195652
# 9   DB00945                 14            0.149002               0.197802
# 10  DB08901                 12            0.119655               0.220000
# 11  DB12147                 10            0.130999               0.229167
# 12  DB00482                  4            0.187097               0.238095
# 13  DB01222                  2            0.235582               0.275000
# 14  DB00959                  2            0.235582               0.275000
# 15  DB09078                 10            0.179780               0.291667
# 16  DB09079                 10            0.179780               0.291667
# 17  DB09074                  2            0.205279               0.300000
# 18  DB00281                  6            0.260971               0.310606
# 19  DB00398                 10            0.228560               0.333333
# 20  DB11800                 10            0.252950               0.354167
# 21  DB06616                  4            0.287097               0.357143
# 22  DB00313                 13            0.355628               0.374057
# 23  DB01259                  2            0.281036               0.375000
# 24  DB08916                  2            0.281036               0.375000
# 25  DB01268                  9            0.312097               0.382979
# 26  DB06589                  9            0.312097               0.404255
# 27  DB15685                  6            0.319529               0.409091
# 28  DB05294                  3            0.328273               0.414634
# 29  DB09061                 34            0.473748               0.455882
# 30  DB01229                  6            0.452412               0.462121
# 31  DB00480                  3            0.426312               0.467480
# 32  DB01234                  4            0.494240               0.511905
# 33  DB08875                  3            0.445920               0.512195
# 34  DB00822                  2            0.478006               0.525000
# 35  DB00834                  3            0.455724               0.540650
# 36  DB14509                  4            0.533525               0.541667
# 37  DB11967                  4            0.515668               0.547619
# 38  DB00277                  9            0.481541               0.561466
# 39  DB01030                  2            0.478006               0.575000
# 40  DB01088                  7            0.575067               0.580952
# 41  DB01065                  6            0.535745               0.590909
# 42  DB00297                  2            0.568915               0.600000
# 43  DB01221                 13            0.621363               0.608597
# 44  DB06626                  3            0.534156               0.609756
# 45  DB08910                  2            0.614370               0.625000
# 46  DB11718                  2            0.553763               0.625000
# 47  DB00668                  8            0.656328               0.630435
# 48  DB08877                  2            0.584066               0.650000
# 49  DB08912                  2            0.553763               0.650000
# 50  DB02546                  5            0.581541               0.674419
# 51  DB01262                  2            0.644673               0.725000
# 52  DB00642                  4            0.687097               0.738095
# 53  DB00316                  4            0.658525               0.738095
# 54  DB00184                  8            0.722033               0.763587
# 55  DB09073                  2            0.674976               0.775000
# 56  DB00712                  2            0.705279               0.775000
# 57  DB12001                  2            0.674976               0.775000
# 58  DB00755                 12            0.682639               0.778333
# 59  DB00441                  2            0.735582               0.825000
# 60  DB00997                  3            0.740038               0.853659
# 61  DB06813                  3            0.769450               0.878049
# 62  DB00773                  2            0.796188               0.900000
# 63  DB00806                  3            0.857685               0.902439
# 64  DB00724                  2            0.856794               0.950000
# 65  DB00982                  2            0.856794               0.975000
# 66  DB00307                  3            0.887097               0.975610
# 67  DB00819                  5            0.970430               1.023256
# 68  DB00745                  2            0.978006               1.025000
# 69  DB00818                  5            0.970430               1.046512
# 70  DB00188                  2            1.038612               1.050000
# 71  DB06772                  2            0.978006               1.075000
# 72  DB01216                  2            1.281036               1.350000
#
#    drug_DrugBankID             drug_name
# 0          DB00530             Erlotinib
# 1          DB11986           Entrectinib
# 2          DB08871              Eribulin
# 3          DB08896           Regorafenib
# 4          DB00203            Sildenafil
# 5          DB08865            Crizotinib
# 6          DB01254             Dasatinib
# 7          DB00641           Simvastatin
# 8          DB12267            Brigatinib
# 9          DB00945  Acetylsalicylic acid
# 10         DB08901             Ponatinib
# 11         DB12147           Erdafitinib
# 12         DB00482             Celecoxib
# 13         DB01222            Budesonide
# 14         DB00959    Methylprednisolone
# 15         DB09078            Lenvatinib
# 16         DB09079            Nintedanib
# 17         DB09074              Olaparib
# 18         DB00281             Lidocaine
# 19         DB00398             Sorafenib
# 20         DB11800             Tivozanib
# 21         DB06616             Bosutinib
# 22         DB00313         Valproic acid
# 23         DB01259             Lapatinib
# 24         DB08916              Afatinib
# 25         DB01268             Sunitinib
# 26         DB06589             Pazopanib
# 27         DB15685         Selpercatinib
# 28         DB05294            Vandetanib
# 29         DB09061           Cannabidiol
# 30         DB01229            Paclitaxel
# 31         DB00480          Lenalidomide
# 32         DB01234         Dexamethasone
# 33         DB08875          Cabozantinib
# 34         DB00822            Disulfiram
# 35         DB00834          Mifepristone
# 36         DB14509     Lithium carbonate
# 37         DB11967           Binimetinib
# 38         DB00277          Theophylline
# 39         DB01030             Topotecan
# 40         DB01088              Iloprost
# 41         DB01065             Melatonin
# 42         DB00297           Bupivacaine
# 43         DB01221              Ketamine
# 44         DB06626              Axitinib
# 45         DB08910          Pomalidomide
# 46         DB11718           Encorafenib
# 47         DB00668           Epinephrine
# 48         DB08877           Ruxolitinib
# 49         DB08912            Dabrafenib
# 50         DB02546            Vorinostat
# 51         DB01262            Decitabine
# 52         DB00642            Pemetrexed
# 53         DB00316         Acetaminophen
# 54         DB00184              Nicotine
# 55         DB09073           Palbociclib
# 56         DB00712          Flurbiprofen
# 57         DB12001           Abemaciclib
# 58         DB00755             Tretinoin
# 59         DB00441           Gemcitabine
# 60         DB00997           Doxorubicin
# 61         DB06813          Pralatrexate
# 62         DB00773             Etoposide
# 63         DB00806        Pentoxifylline
# 64         DB00724             Imiquimod
# 65         DB00982          Isotretinoin
# 66         DB00307            Bexarotene
# 67         DB00819         Acetazolamide
# 68         DB00745             Modafinil
# 69         DB00818              Propofol
# 70         DB00188            Bortezomib
# 71         DB06772           Cabazitaxel
# 72         DB01216           Finasteride
